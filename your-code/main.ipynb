# %% [markdown]
# # Probability

# %% [markdown]
# ## Challenge 1
# There is a box with 10 white balls, 12 red balls and 8 black balls. Calculate the probability of:
# * Taking a white ball out.
# * Taking a white ball on first extraction and a black ball out on second extraction without replacing the first one.
# * Taking a white ball on first extraction and a black ball out on second extraction replacing the first one.
# * Taking 3 balls and them being all different colours.

# %%
import math

# %%
white_balls = 10
red_balls = 12
black_balls = 8
total = white_balls + red_balls + black_balls
total
# Out:
# 30

# %%
probability_white = white_balls/total
probability_white
# Out:
# 0.3333333333333333

# %%
favorable_outcomes1 = math.comb(white_balls, 1) * math.comb(black_balls, 1)
total_pairs1 = math.comb(total, 2)

p_unordered1 = favorable_outcomes1 / total_pairs1
p_ordered_wb = p_unordered / 2         # given that we're choosing a specific order out of 2 total possible orders

print(p_ordered_wb)
# Out:
# 0.09195402298850575

# %%
probability_black = black_balls/total
p_ordered_wb_replace = probability_white*probability_black
p_ordered_wb_replace
# Out:
# 0.08888888888888888

# %%
favorable_outcomes2 = math.comb(white_balls, 1) * math.comb(black_balls, 1) * math.comb(red_balls, 1)
total_pairs2 = math.comb(total, 3)

n_different_orders = math.factorial(3)

p_unordered2 = favorable_outcomes2 / total_pairs2

print(p_unordered2)

# OR:

p_unordered2_alt = n_different_orders*(white_balls/total)*(red_balls/(total-1))*(black_balls/(total-2))

print(p_unordered2_alt)
# Out:
# 0.23645320197044334
# 0.23645320197044334

# %% [markdown]
# ## Challenge 2
#
# You want to go on picnic on Saturday. You hate rain, and would know to plan your weekend. To help you make a decision, you gather the following data about rainy days:
#
# * 40% of all days are cloudy.
# * About 50% of cloudy days are rainy.
# * About 20% of non-cloudy days are rainy.
#
# What is the chance of rain during next Saturday?

# %%
probability_cloudy = 0.4
probability_rain_given_cloudy = 0.5
probability_rain_given_not_cloudy = 0.2

probability_rain = probability_rain_given_cloudy * probability_cloudy + probability_rain_given_not_cloudy * (1 - probability_cloudy)
print(probability_rain)
# Out:
# 0.32

# %% [markdown]
# ## Challenge 3
#
# A and B are events of a probability such that $P(A) = 0.3$, $P(B) = 0.6$ and $P(A \cap B) = 0.1$
#
# Which of the following statements are true?
# **HINT: draw a big Venn Diagram by your side**
# * $P(\overline{A}) = 0.7$
# * $P(A \cup B) = 0.6$
# * $P(A \cap \overline{B}) = 0.2$
# * $P(A \cup \overline{A}) = 1$
# * $P(A \cap (B \cup \overline{B})) = 0.4$
# * $P(\overline{A} \cap \overline{B}) = 0.3$
# * $P(\overline{A \cap B}) = 0.9$

# %%
probability_A = 0.3
probability_B = 0.6
probability_AandB = 0.1

#1 - TRUE STATEMENT
probability_notA = 1-probability_A
print(probability_notA)

#2 - FALSE STATEMENT
probability_AorB = probability_A + probability_B - probability_AandB
print(probability_AorB)

#3 - TRUE STATEMENT

probabbility_A_and_notB = probability_A - probability_AandB
print(probabbility_A_and_notB)

#4 - TRUE STATEMENT
print(probability_A + probability_notA)

#5 - FALSE STATEMENT

# eventually, this is equal to probability(A)

print(probability_A)

#6 - FALSE STATEMENT

probability_not_AorB = 1 - probability_AorB
print(probability_not_AorB)

#7 - TRUE STATEMENT
probability_not_AandB = 1- probability_AandB
print(probability_not_AandB)
# Out:
# 0.7
# 0.7999999999999999
# 0.19999999999999998
# 1.0
# 0.3
# 0.20000000000000007
# 0.9

# %% [markdown]
# ## Challenge 4
#
#  * If someone flies to China, the probability of getting Covid is 1%
#  * If someone flies to Italy, the probability of getting Covid is 20%
#
# I roll 1 dice with numbers 1, 2, 3, 4, 5, 6:
#  * If 1: I fly to Italy
#  * If not 1: I fly to China
#
# During my trip, I got Covid. What is the probability that I flew to China?

# %%
probability_Italy = 1/6
probability_China = 1 - probability_Italy

probability_Covid_China = 0.01
probability_Covid_Italy = 0.2

probability_China_Covid = 0.01*probability_China/((0.01*probability_China)+(0.2*probability_Italy))
probability_China_Covid
# Out:
# 0.2

# %% [markdown]
# ## BONUS
#
# You roll 2 dice. What is the probability that the sum of the numbers is 7? And 8? And 9? Then simulate 10000 times and draw a countplot.

# %% [markdown]
# your explanation here

# %%
import random
import seaborn as sns
import matplotlib.pyplot as plt

probability_7 = 6/36
print(probability_7)

probability_8 = 5/36
print(probability_8)

probability_9 = 4/36
print(probability_9)


number_trials = 10000
results = []

for _ in range(number_trials):
    sum = random.randint(1, 6) + random.randint(1, 6)
    results.append(sum)

sns.countplot(x=results)
plt.xlabel('Sum of Face Values')
plt.ylabel('Number of Sum Occurences')
plt.title('Trial Results')
plt.show()
# Out:
# 0.16666666666666666
# 0.1388888888888889
# 0.1111111111111111
